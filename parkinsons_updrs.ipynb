# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("parkinsons_updrs.csv")

# %%
df
# Out:
#       subject  age  sex  test_time  motor_UPDRS  total_UPDRS  Jitter_percent  \
# 0           1   72    0    5.64310       28.199       34.398         0.00662
# 1           1   72    0   12.66600       28.447       34.894         0.00300
# 2           1   72    0   19.68100       28.695       35.389         0.00481
# 3           1   72    0   25.64700       28.905       35.810         0.00528
# 4           1   72    0   33.64200       29.187       36.375         0.00335
# 5           1   72    0   40.65200       29.435       36.870         0.00353
# 6           1   72    0   47.64900       29.682       37.363         0.00422
# 7           1   72    0   54.64000       29.928       37.857         0.00476
# 8           1   72    0   61.66900       30.177       38.353         0.00432
# 9           1   72    0   68.68800       30.424       38.849         0.00496
# 10          1   72    0   75.65300       30.670       39.340         0.00465
# ...

# %%
df.columns
# Out:
# Index([u'subject', u'age', u'sex', u'test_time', u'motor_UPDRS',
#        u'total_UPDRS', u'Jitter_percent', u'Jitter_Abs', u'Jitter_RAP',
#        u'Jitter_PPQ5', u'Jitter_DDP', u'Shimmer', u'Shimmer_dB',
#        u'Shimmer_APQ3', u'Shimmer_APQ5', u'Shimmer_APQ11', u'Shimmer_DDA',
#        u'NHR', u'HNR', u'RPDE', u'DFA', u'PPE'],
#       dtype='object')

# %% [markdown]
# <b> EDA </b>

# %%
df.age.value_counts()
# Out:
# 58    429
# 66    422
# 65    407
# 57    385
# 73    385
# 68    317
# 72    310
# 59    299
# 75    286
# 67    283
# 74    271
# 55    267
# 49    256
# 62    236
# 78    168
# 71    165
# 60    156
# 63    156
# 61    150
# 76    144
# 85    142
# 56    140
# 36    101
# Name: age, dtype: int64

# %%
df.describe()
# Out:
#            subject          age          sex    test_time  motor_UPDRS  \
# count  5875.000000  5875.000000  5875.000000  5875.000000  5875.000000
# mean     21.494128    64.804936     0.317787    92.863722    21.296229
# std      12.372279     8.821524     0.465656    53.445602     8.129282
# min       1.000000    36.000000     0.000000    -4.262500     5.037700
# 25%      10.000000    58.000000     0.000000    46.847500    15.000000
# 50%      22.000000    65.000000     0.000000    91.523000    20.871000
# 75%      33.000000    72.000000     1.000000   138.445000    27.596500
# max      42.000000    85.000000     1.000000   215.490000    39.511000
#
#        total_UPDRS  Jitter_percent   Jitter_Abs   Jitter_RAP  Jitter_PPQ5  \
# count  5875.000000     5875.000000  5875.000000  5875.000000  5875.000000
# mean     29.018942        0.006154     0.000044     0.002987     0.003277
# std      10.700283        0.005624     0.000036     0.003124     0.003732
# ...

# %%
df.age.describe()
# Out:
# count    5875.000000
# mean       64.804936
# std         8.821524
# min        36.000000
# 25%        58.000000
# 50%        65.000000
# 75%        72.000000
# max        85.000000
# Name: age, dtype: float64

# %%
df.age.hist(bins=10)

# %%
df[df.age.isnull()]
# Out:
# Empty DataFrame
# Columns: [subject, age, sex, test_time, motor_UPDRS, total_UPDRS, Jitter_percent, Jitter_Abs, Jitter_RAP, Jitter_PPQ5, Jitter_DDP, Shimmer, Shimmer_dB, Shimmer_APQ3, Shimmer_APQ5, Shimmer_APQ11, Shimmer_DDA, NHR, HNR, RPDE, DFA, PPE]
# Index: []
#
# [0 rows x 22 columns]

# %%
df[df.age==0]
# Out:
# Empty DataFrame
# Columns: [subject, age, sex, test_time, motor_UPDRS, total_UPDRS, Jitter_percent, Jitter_Abs, Jitter_RAP, Jitter_PPQ5, Jitter_DDP, Shimmer, Shimmer_dB, Shimmer_APQ3, Shimmer_APQ5, Shimmer_APQ11, Shimmer_DDA, NHR, HNR, RPDE, DFA, PPE]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.sex.describe()
# Out:
# count    5875.000000
# mean        0.317787
# std         0.465656
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: sex, dtype: float64

# %%
df.sex.value_counts()
# Out:
# 0    4008
# 1    1867
# Name: sex, dtype: int64

# %%
df.sex.value_counts().plot(kind='bar')

# %%
df.test_time.value_counts()
# Out:
# 119.3400    15
# 147.3400    14
# 126.4200    12
# 126.2600    12
# 133.3900    12
# 105.3700    11
# 136.8000    11
# 168.3900    11
# 133.7700    11
# 105.4000    10
# 123.8300    10
# 119.3500     9
# 154.3400     9
# 132.4100     9
# 117.3300     9
# 158.8000     9
# 119.3800     7
# 154.3000     7
# 118.3000     7
# 146.3300     7
# 146.4300     7
# 112.4100     7
# 101.7200     6
# 125.8100     6
# 166.3300     6
# 103.3600     6
# 143.4800     6
# 181.3100     6
# 126.4900     6
# 139.3500     6
#             ..
# 16.4390      1
# 73.7810      1
# 66.8520      1
# 10.5850      1
# 34.5590      1
# 36.3880      1
# 21.3360      1
# 49.3460      1
# 67.8480      1
# 28.7240      1
# 88.7890      1
# 5.3410       1
# 87.3540      1
# 93.5830      1
# 75.4250      1
# 9.7104       1
# 6.3674       1
# 80.5990      1
# 11.3570      1
# 96.6360      1
# 78.7030      1
# 17.3120      1
# 99.3600      1
# 62.4100      1
# 64.5970      1
# 46.5850      1
# 23.4500      1
# ...

# %%
df.test_time.describe()
# Out:
# count    5875.000000
# mean       92.863722
# std        53.445602
# min        -4.262500
# 25%        46.847500
# 50%        91.523000
# 75%       138.445000
# max       215.490000
# Name: test_time, dtype: float64

# %%
df.test_time.hist(bins=10)

# %%
df.motor_UPDRS.value_counts()
# Out:
# 15.0000    143
# 12.0000    131
# 31.0000     90
# 18.0000     82
# 6.0000      72
# 17.0000     69
# 10.9490     12
# 23.5410     12
# 33.6430     12
# 29.7970     12
# 31.7760     12
# 24.6590     11
# 35.3750     11
# 23.4470     11
# 18.2460     11
# 26.9950     11
# 24.9860     10
# 17.6070      9
# 16.6620      9
# 25.3950      9
# 14.6460      9
# 26.7960      9
# 29.9710      9
# 11.7820      8
# 30.8920      7
# 16.6070      6
# 13.0440      6
# 20.3510      6
# 16.7770      6
# 30.9170      6
#           ...
# 8.3170       1
# 26.9940      1
# 24.4010      1
# 5.4370       1
# 6.5409       1
# 25.6620      1
# 35.3760      1
# 7.1037       1
# 9.9457       1
# 36.1520      1
# 9.3276       1
# 36.5610      1
# 15.9900      1
# 21.7430      1
# 9.3274       1
# 32.0130      1
# 30.2310      1
# 7.4545       1
# 20.6770      1
# 27.5950      1
# 8.7208       1
# 27.1140      1
# 8.7031       1
# 30.2830      1
# 9.3743       1
# 25.9610      1
# 11.8140      1
# ...

# %%
df.motor_UPDRS.hist(bins=10)

# %%
df.motor_UPDRS.describe()
# Out:
# count    5875.000000
# mean       21.296229
# std         8.129282
# min         5.037700
# 25%        15.000000
# 50%        20.871000
# 75%        27.596500
# max        39.511000
# Name: motor_UPDRS, dtype: float64

# %%
df[df.motor_UPDRS.isnull()]
# Out:
# Empty DataFrame
# Columns: [subject, age, sex, test_time, motor_UPDRS, total_UPDRS, Jitter_percent, Jitter_Abs, Jitter_RAP, Jitter_PPQ5, Jitter_DDP, Shimmer, Shimmer_dB, Shimmer_APQ3, Shimmer_APQ5, Shimmer_APQ11, Shimmer_DDA, NHR, HNR, RPDE, DFA, PPE]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.total_UPDRS.describe()
# Out:
# count    5875.000000
# mean       29.018942
# std        10.700283
# min         7.000000
# 25%        21.371000
# 50%        27.576000
# 75%        36.399000
# max        54.992000
# Name: total_UPDRS, dtype: float64

# %%
df[df.total_UPDRS.isnull()]
# Out:
# Empty DataFrame
# Columns: [subject, age, sex, test_time, motor_UPDRS, total_UPDRS, Jitter_percent, Jitter_Abs, Jitter_RAP, Jitter_PPQ5, Jitter_DDP, Shimmer, Shimmer_dB, Shimmer_APQ3, Shimmer_APQ5, Shimmer_APQ11, Shimmer_DDA, NHR, HNR, RPDE, DFA, PPE]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.total_UPDRS.hist(bins=10)

# %%
df.Jitter_percent.describe()
# Out:
# count    5875.000000
# mean        0.006154
# std         0.005624
# min         0.000830
# 25%         0.003580
# 50%         0.004900
# 75%         0.006800
# max         0.099990
# Name: Jitter_percent, dtype: float64

# %%
df[df.Jitter_percent.isnull()]
# Out:
# Empty DataFrame
# Columns: [subject, age, sex, test_time, motor_UPDRS, total_UPDRS, Jitter_percent, Jitter_Abs, Jitter_RAP, Jitter_PPQ5, Jitter_DDP, Shimmer, Shimmer_dB, Shimmer_APQ3, Shimmer_APQ5, Shimmer_APQ11, Shimmer_DDA, NHR, HNR, RPDE, DFA, PPE]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.Jitter_percent.hist(bins=3)

# %%
df.Jitter_Abs.describe()
# Out:
# count    5875.000000
# mean        0.000044
# std         0.000036
# min         0.000002
# 25%         0.000022
# 50%         0.000034
# 75%         0.000053
# max         0.000446
# Name: Jitter_Abs, dtype: float64

# %%
df[df.Jitter_Abs.isnull()]
# Out:
# Empty DataFrame
# Columns: [subject, age, sex, test_time, motor_UPDRS, total_UPDRS, Jitter_percent, Jitter_Abs, Jitter_RAP, Jitter_PPQ5, Jitter_DDP, Shimmer, Shimmer_dB, Shimmer_APQ3, Shimmer_APQ5, Shimmer_APQ11, Shimmer_DDA, NHR, HNR, RPDE, DFA, PPE]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.Jitter_Abs.hist(bins=3)

# %%
df.Jitter_RAP.describe()
# Out:
# count    5875.000000
# mean        0.002987
# std         0.003124
# min         0.000330
# 25%         0.001580
# 50%         0.002250
# 75%         0.003290
# max         0.057540
# Name: Jitter_RAP, dtype: float64

# %%
df[df.Jitter_RAP.isnull()]
# Out:
# Empty DataFrame
# Columns: [subject, age, sex, test_time, motor_UPDRS, total_UPDRS, Jitter_percent, Jitter_Abs, Jitter_RAP, Jitter_PPQ5, Jitter_DDP, Shimmer, Shimmer_dB, Shimmer_APQ3, Shimmer_APQ5, Shimmer_APQ11, Shimmer_DDA, NHR, HNR, RPDE, DFA, PPE]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.Jitter_RAP.hist(bins=2)

# %%
df.Jitter_PPQ5.describe()
# Out:
# count    5875.000000
# mean        0.003277
# std         0.003732
# min         0.000430
# 25%         0.001820
# 50%         0.002490
# 75%         0.003460
# max         0.069560
# Name: Jitter_PPQ5, dtype: float64

# %%
df[df.Jitter_PPQ5.isnull()]
# Out:
# Empty DataFrame
# Columns: [subject, age, sex, test_time, motor_UPDRS, total_UPDRS, Jitter_percent, Jitter_Abs, Jitter_RAP, Jitter_PPQ5, Jitter_DDP, Shimmer, Shimmer_dB, Shimmer_APQ3, Shimmer_APQ5, Shimmer_APQ11, Shimmer_DDA, NHR, HNR, RPDE, DFA, PPE]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.Jitter_PPQ5.hist(bins=3)

# %%
df.Jitter_DDP.describe()
# Out:
# count    5875.000000
# mean        0.008962
# std         0.009371
# min         0.000980
# 25%         0.004730
# 50%         0.006750
# 75%         0.009870
# max         0.172630
# Name: Jitter_DDP, dtype: float64

# %%
df[df.Jitter_DDP.isnull()]
# Out:
# Empty DataFrame
# Columns: [subject, age, sex, test_time, motor_UPDRS, total_UPDRS, Jitter_percent, Jitter_Abs, Jitter_RAP, Jitter_PPQ5, Jitter_DDP, Shimmer, Shimmer_dB, Shimmer_APQ3, Shimmer_APQ5, Shimmer_APQ11, Shimmer_DDA, NHR, HNR, RPDE, DFA, PPE]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.Jitter_DDP.hist(bins=3)

# %%
df.Shimmer.describe()
# Out:
# count    5875.000000
# mean        0.034035
# std         0.025835
# min         0.003060
# 25%         0.019120
# 50%         0.027510
# 75%         0.039750
# max         0.268630
# Name: Shimmer, dtype: float64

# %%
df[df.Shimmer.isnull()]
# Out:
# Empty DataFrame
# Columns: [subject, age, sex, test_time, motor_UPDRS, total_UPDRS, Jitter_percent, Jitter_Abs, Jitter_RAP, Jitter_PPQ5, Jitter_DDP, Shimmer, Shimmer_dB, Shimmer_APQ3, Shimmer_APQ5, Shimmer_APQ11, Shimmer_DDA, NHR, HNR, RPDE, DFA, PPE]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.Shimmer.hist(bins=3)

# %%
df.Shimmer_dB.describe()
# Out:
# count    5875.000000
# mean        0.310960
# std         0.230254
# min         0.026000
# 25%         0.175000
# 50%         0.253000
# 75%         0.365000
# max         2.107000
# Name: Shimmer_dB, dtype: float64

# %%
df[df.Shimmer.isnull()]
# Out:
# Empty DataFrame
# Columns: [subject, age, sex, test_time, motor_UPDRS, total_UPDRS, Jitter_percent, Jitter_Abs, Jitter_RAP, Jitter_PPQ5, Jitter_DDP, Shimmer, Shimmer_dB, Shimmer_APQ3, Shimmer_APQ5, Shimmer_APQ11, Shimmer_DDA, NHR, HNR, RPDE, DFA, PPE]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.Shimmer_dB.hist(bins=3)

# %%
df.Shimmer_APQ3.describe()
# Out:
# count    5875.000000
# mean        0.017156
# std         0.013237
# min         0.001610
# 25%         0.009280
# 50%         0.013700
# 75%         0.020575
# max         0.162670
# Name: Shimmer_APQ3, dtype: float64

# %%
df[df.Shimmer_APQ3.isnull()]
# Out:
# Empty DataFrame
# Columns: [subject, age, sex, test_time, motor_UPDRS, total_UPDRS, Jitter_percent, Jitter_Abs, Jitter_RAP, Jitter_PPQ5, Jitter_DDP, Shimmer, Shimmer_dB, Shimmer_APQ3, Shimmer_APQ5, Shimmer_APQ11, Shimmer_DDA, NHR, HNR, RPDE, DFA, PPE]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.Shimmer_APQ3.hist(bins=2)

# %%
df.Shimmer_APQ5.describe()
# Out:
# count    5875.000000
# mean        0.020144
# std         0.016664
# min         0.001940
# 25%         0.010790
# 50%         0.015940
# 75%         0.023755
# max         0.167020
# Name: Shimmer_APQ5, dtype: float64

# %%
df[df.Shimmer_APQ5.isnull()]
# Out:
# Empty DataFrame
# Columns: [subject, age, sex, test_time, motor_UPDRS, total_UPDRS, Jitter_percent, Jitter_Abs, Jitter_RAP, Jitter_PPQ5, Jitter_DDP, Shimmer, Shimmer_dB, Shimmer_APQ3, Shimmer_APQ5, Shimmer_APQ11, Shimmer_DDA, NHR, HNR, RPDE, DFA, PPE]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.Shimmer_APQ5.hist(bins=3)

# %%
df.Shimmer_APQ11.describe()
# Out:
# count    5875.000000
# mean        0.027481
# std         0.019986
# min         0.002490
# 25%         0.015665
# 50%         0.022710
# 75%         0.032715
# max         0.275460
# Name: Shimmer_APQ11, dtype: float64

# %%
df[df.Shimmer_APQ11.isnull()]
# Out:
# Empty DataFrame
# Columns: [subject, age, sex, test_time, motor_UPDRS, total_UPDRS, Jitter_percent, Jitter_Abs, Jitter_RAP, Jitter_PPQ5, Jitter_DDP, Shimmer, Shimmer_dB, Shimmer_APQ3, Shimmer_APQ5, Shimmer_APQ11, Shimmer_DDA, NHR, HNR, RPDE, DFA, PPE]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.Shimmer_APQ11.hist(bins=2)

# %%
df.Shimmer_DDA.describe()
# Out:
# count    5875.000000
# mean        0.051467
# std         0.039711
# min         0.004840
# 25%         0.027830
# 50%         0.041110
# 75%         0.061735
# max         0.488020
# Name: Shimmer_DDA, dtype: float64

# %%
df[df.Shimmer_DDA.isnull()]
# Out:
# Empty DataFrame
# Columns: [subject, age, sex, test_time, motor_UPDRS, total_UPDRS, Jitter_percent, Jitter_Abs, Jitter_RAP, Jitter_PPQ5, Jitter_DDP, Shimmer, Shimmer_dB, Shimmer_APQ3, Shimmer_APQ5, Shimmer_APQ11, Shimmer_DDA, NHR, HNR, RPDE, DFA, PPE]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.Shimmer_DDA.hist(bins=3)

# %%
df.NHR.describe()
# Out:
# count    5875.000000
# mean        0.032120
# std         0.059692
# min         0.000286
# 25%         0.010955
# 50%         0.018448
# 75%         0.031463
# max         0.748260
# Name: NHR, dtype: float64

# %%
df[df.NHR.isnull()]
# Out:
# Empty DataFrame
# Columns: [subject, age, sex, test_time, motor_UPDRS, total_UPDRS, Jitter_percent, Jitter_Abs, Jitter_RAP, Jitter_PPQ5, Jitter_DDP, Shimmer, Shimmer_dB, Shimmer_APQ3, Shimmer_APQ5, Shimmer_APQ11, Shimmer_DDA, NHR, HNR, RPDE, DFA, PPE]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.NHR.hist(bins=3)

# %%
df.HNR.describe()
# Out:
# count    5875.000000
# mean       21.679495
# std         4.291096
# min         1.659000
# 25%        19.406000
# 50%        21.920000
# 75%        24.444000
# max        37.875000
# Name: HNR, dtype: float64

# %%
df[df.HNR.isnull()]
# Out:
# Empty DataFrame
# Columns: [subject, age, sex, test_time, motor_UPDRS, total_UPDRS, Jitter_percent, Jitter_Abs, Jitter_RAP, Jitter_PPQ5, Jitter_DDP, Shimmer, Shimmer_dB, Shimmer_APQ3, Shimmer_APQ5, Shimmer_APQ11, Shimmer_DDA, NHR, HNR, RPDE, DFA, PPE]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.HNR.hist(bins=10)

# %%
df.RPDE.describe()
# Out:
# count    5875.000000
# mean        0.541473
# std         0.100986
# min         0.151020
# 25%         0.469785
# 50%         0.542250
# 75%         0.614045
# max         0.966080
# Name: RPDE, dtype: float64

# %%
df[df.RPDE.isnull()]
# Out:
# Empty DataFrame
# Columns: [subject, age, sex, test_time, motor_UPDRS, total_UPDRS, Jitter_percent, Jitter_Abs, Jitter_RAP, Jitter_PPQ5, Jitter_DDP, Shimmer, Shimmer_dB, Shimmer_APQ3, Shimmer_APQ5, Shimmer_APQ11, Shimmer_DDA, NHR, HNR, RPDE, DFA, PPE]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.RPDE.hist(bins=3)

# %%
df.DFA.describe()
# Out:
# count    5875.000000
# mean        0.653240
# std         0.070902
# min         0.514040
# 25%         0.596180
# 50%         0.643600
# 75%         0.711335
# max         0.865600
# Name: DFA, dtype: float64

# %%
df[df.DFA.isnull()]
# Out:
# Empty DataFrame
# Columns: [subject, age, sex, test_time, motor_UPDRS, total_UPDRS, Jitter_percent, Jitter_Abs, Jitter_RAP, Jitter_PPQ5, Jitter_DDP, Shimmer, Shimmer_dB, Shimmer_APQ3, Shimmer_APQ5, Shimmer_APQ11, Shimmer_DDA, NHR, HNR, RPDE, DFA, PPE]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.DFA.hist(bins=5)

# %%
df.PPE.describe()
# Out:
# count    5875.000000
# mean        0.219589
# std         0.091498
# min         0.021983
# 25%         0.156340
# 50%         0.205500
# 75%         0.264490
# max         0.731730
# Name: PPE, dtype: float64

# %%
df[df.PPE.isnull()]
# Out:
# Empty DataFrame
# Columns: [subject, age, sex, test_time, motor_UPDRS, total_UPDRS, Jitter_percent, Jitter_Abs, Jitter_RAP, Jitter_PPQ5, Jitter_DDP, Shimmer, Shimmer_dB, Shimmer_APQ3, Shimmer_APQ5, Shimmer_APQ11, Shimmer_DDA, NHR, HNR, RPDE, DFA, PPE]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.PPE.hist(bins=3)

# %%
df.head()
# Out:
#    subject  age  sex  test_time  motor_UPDRS  total_UPDRS  Jitter_percent  \
# 0        1   72    0     5.6431       28.199       34.398         0.00662
# 1        1   72    0    12.6660       28.447       34.894         0.00300
# 2        1   72    0    19.6810       28.695       35.389         0.00481
# 3        1   72    0    25.6470       28.905       35.810         0.00528
# 4        1   72    0    33.6420       29.187       36.375         0.00335
#
#    Jitter_Abs  Jitter_RAP  Jitter_PPQ5   ...     Shimmer_dB  Shimmer_APQ3  \
# 0    0.000034     0.00401      0.00317   ...          0.230       0.01438
# 1    0.000017     0.00132      0.00150   ...          0.179       0.00994
# 2    0.000025     0.00205      0.00208   ...          0.181       0.00734
# 3    0.000027     0.00191      0.00264   ...          0.327       0.01106
# 4    0.000020     0.00093      0.00130   ...          0.176       0.00679
#
#    Shimmer_APQ5  Shimmer_APQ11  Shimmer_DDA       NHR     HNR     RPDE  \
# ...

# %%
X = df.drop(['sex'], axis=1)

# %%
X.head()
# Out:
#    subject  age  test_time  motor_UPDRS  total_UPDRS  Jitter_percent  \
# 0        1   72     5.6431       28.199       34.398         0.00662
# 1        1   72    12.6660       28.447       34.894         0.00300
# 2        1   72    19.6810       28.695       35.389         0.00481
# 3        1   72    25.6470       28.905       35.810         0.00528
# 4        1   72    33.6420       29.187       36.375         0.00335
#
#    Jitter_Abs  Jitter_RAP  Jitter_PPQ5  Jitter_DDP   ...     Shimmer_dB  \
# 0    0.000034     0.00401      0.00317     0.01204   ...          0.230
# 1    0.000017     0.00132      0.00150     0.00395   ...          0.179
# 2    0.000025     0.00205      0.00208     0.00616   ...          0.181
# 3    0.000027     0.00191      0.00264     0.00573   ...          0.327
# 4    0.000020     0.00093      0.00130     0.00278   ...          0.176
#
#    Shimmer_APQ3  Shimmer_APQ5  Shimmer_APQ11  Shimmer_DDA       NHR     HNR  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[-1.65659628,  0.81569539, -1.63209025, ..., -1.21406557,
#         -1.47849968, -0.65065821],
#        [-1.65659628,  0.81569539, -1.5006763 , ..., -1.05511879,
#         -1.24788006, -1.21858474],
#        [-1.65659628,  0.81569539, -1.36941017, ..., -0.78485974,
#         -1.5401393 , -0.10328021],
#        ...,
#        [ 1.65754564, -0.43136086,  1.19676305, ..., -0.62937908,
#         -1.04885603, -0.85275524],
#        [ 1.65754564, -0.43136086,  1.32606439, ...,  0.26914065,
#         -1.26903782, -0.8476181 ],
#        [ 1.65754564, -0.43136086,  1.45704984, ...,  0.44175389,
#         -1.163249  , -0.72388969]])

# %%
def find_k (X, k_range, sample_percent=1):
    """
    k_range: a list of possible k values
    X, the data we're clustering on
    """
    from sklearn.cluster import KMeans
    import matplotlib.pyplot as plt
    import numpy as np
    from scipy.spatial.distance import cdist
    from sklearn.metrics import pairwise_distances

    N = X.shape[0]
    sampleSize = X.shape[0] * sample_percent

    if sampleSize > 0:
        index = np.arange(np.shape(X)[0])
        np.random.shuffle(index)
        X =  X[index, :]


    mean_distortions=[]
    for k in k_range:
        #cluster using k, then calculate the mean distortion (average distance to closest centroid)
        kmeans_model = KMeans(n_clusters=k, init='k-means++', n_jobs=-1).fit(X)
        mean_distortions.append(sum(np.min(pairwise_distances(X, kmeans_model.cluster_centers_,
                                                              metric='euclidean'),axis=1)) / X.shape[0])


    #visualize results
    plt.plot(k_range, mean_distortions)
    plt.xlabel("K Value")
    plt.ylabel("Mean Distortion")
    plt.title("Elbow Graph for Mean Distortion per K")
    plt.show()

# %%
find_k(np.matrix(X), range(1,10),1)

# %%
from sklearn.cluster import KMeans
kmeans_model = KMeans(n_clusters=3, random_state=42)
kmeans_model.fit(X_scaled)
# Out:
# KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=3, n_init=10,
#     n_jobs=1, precompute_distances='auto', random_state=42, tol=0.0001,
#     verbose=0)

# %%
df['labels'] = kmeans_model.labels_

# %%
df.head()
# Out:
#    subject  age  sex  test_time  motor_UPDRS  total_UPDRS  Jitter_percent  \
# 0        1   72    0     5.6431       28.199       34.398         0.00662
# 1        1   72    0    12.6660       28.447       34.894         0.00300
# 2        1   72    0    19.6810       28.695       35.389         0.00481
# 3        1   72    0    25.6470       28.905       35.810         0.00528
# 4        1   72    0    33.6420       29.187       36.375         0.00335
#
#    Jitter_Abs  Jitter_RAP  Jitter_PPQ5   ...    Shimmer_APQ3  Shimmer_APQ5  \
# 0    0.000034     0.00401      0.00317   ...         0.01438       0.01309
# 1    0.000017     0.00132      0.00150   ...         0.00994       0.01072
# 2    0.000025     0.00205      0.00208   ...         0.00734       0.00844
# 3    0.000027     0.00191      0.00264   ...         0.01106       0.01265
# 4    0.000020     0.00093      0.00130   ...         0.00679       0.00929
#
# ...

# %%
df[df['labels'] == 1]
# Out:
#       subject  age  sex  test_time  motor_UPDRS  total_UPDRS  Jitter_percent  \
# 0           1   72    0     5.6431       28.199       34.398         0.00662
# 1           1   72    0    12.6660       28.447       34.894         0.00300
# 2           1   72    0    19.6810       28.695       35.389         0.00481
# 3           1   72    0    25.6470       28.905       35.810         0.00528
# 4           1   72    0    33.6420       29.187       36.375         0.00335
# 5           1   72    0    40.6520       29.435       36.870         0.00353
# 6           1   72    0    47.6490       29.682       37.363         0.00422
# 7           1   72    0    54.6400       29.928       37.857         0.00476
# 8           1   72    0    61.6690       30.177       38.353         0.00432
# 9           1   72    0    68.6880       30.424       38.849         0.00496
# 10          1   72    0    75.6530       30.670       39.340         0.00465
# ...

# %%
df[df['labels'] == 0]
# Out:
#       subject  age  sex  test_time  motor_UPDRS  total_UPDRS  Jitter_percent  \
# 16          1   72    0  117.66000       33.178       42.904         0.00693
# 21          1   72    0  152.64000       35.509       46.013         0.00629
# 25          1   72    0   12.66700       28.447       34.894         0.00950
# 30          1   72    0   47.64900       29.682       37.363         0.00772
# 36          1   72    0   89.63500       31.309       40.412         0.00991
# 40          1   72    0  117.67000       33.178       42.904         0.00806
# 53          1   72    0   33.64400       29.187       36.375         0.00575
# 72          1   72    0  166.64000       36.443       47.257         0.00573
# 84          1   72    0   75.65600       30.670       39.340         0.00719
# 109         1   72    0   75.65600       30.670       39.340         0.00708
# 137         1   72    0   96.63700       31.776       41.034         0.00488
# ...

# %%
from sklearn.manifold import TSNE
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

model = TSNE(n_components=3, learning_rate=12, random_state=10)
X_tsne = model.fit_transform(X) 
plt.figure(figsize=(10,10))
ax = plt.subplot(111, projection='3d')
ax.scatter(X_tsne[:, 0], X_tsne[:, 1],X_tsne[:,2], c=kmeans_model.labels_)
